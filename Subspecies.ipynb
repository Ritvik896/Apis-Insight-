# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os
from sklearn.model_selection import train_test_split
import tensorflow
import skimage
import skimage.io
import skimage.transform
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPool2D
from keras.layers import Dropout, BatchNormalization,LeakyReLU, Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, ReduceLROnPlateau
from keras.utils import to_categorical
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Load the saved model
from keras.models import model_from_json

# %%
np.random.seed(11)
tensorflow.random.set_seed(11)

# %%
img_folder='C:\\Users\\satvi\\OneDrive\\Pictures\\Desktop\\Test1\\static1\\images\\'
img_width=128 
#check path 
img_height=128
img_channels=3
bees=pd.read_csv('C:\\Users\\satvi\\OneDrive\\Pictures\\Desktop\\Test1\\bee_data_mod.csv', 
                index_col=False,  
                parse_dates={'datetime':[1,2]},
                dtype={'subspecies':'category', 'health':'category','caste':'category'})
def read_img(file):
    img = skimage.io.imread(img_folder + file)
    img = skimage.transform.resize(img, (img_width, img_height), mode='reflect')
    return img[:,:,:img_channels]

bees.dropna(inplace=True)
img_exists = bees['file'].apply(lambda f: os.path.exists(img_folder + f))
bees = bees[img_exists]
# Out:
# C:\Users\satvi\AppData\Local\Temp\ipykernel_23996\2525093836.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bees=pd.read_csv('C:\\Users\\satvi\\OneDrive\\Pictures\\Desktop\\Test1\\bee_data_mod.csv',

# %%
bees.head()
# Out:
#              datetime         file              location  zip code  \
# 0 2018-08-25 14:00:00  001_043.png  Kalakadu, Tamil Nadu    627007
# 1 2018-08-25 14:00:00  001_044.png  Kalakadu, Tamil Nadu    627007
# 2 2018-08-25 14:00:00  001_046.png  Kalakadu, Tamil Nadu    627007
# 3 2018-08-25 14:00:00  001_047.png  Kalakadu, Tamil Nadu    627007
# 4 2018-08-25 14:00:00  001_050.png  Kalakadu, Tamil Nadu    627007
#
#    subspecies   health  pollen_carrying   caste
# 0  Dammer bee  healthy            False  worker
# 1  Dammer bee  healthy            False  worker
# 2  Dammer bee  healthy            False  worker
# 3  Dammer bee  healthy            False  worker
# 4  Dammer bee  healthy            False  worker

# %%
bees.tail()
# Out:
#                 datetime         file              location  zip code  \
# 1789 2018-08-17 17:50:00  030_800.png  Alchuna, Uttrakhand     263136
# 1790 2018-08-17 17:50:00  030_814.png  Alchuna, Uttrakhand     263136
# 1791 2018-08-17 17:50:00  030_828.png  Alchuna, Uttrakhand     263136
# 1792 2018-08-17 17:50:00  030_829.png  Alchuna, Uttrakhand     263136
# 1793 2018-08-17 17:50:00  030_815.png  Alchuna, Uttrakhand     263136
#
#              subspecies     health  pollen_carrying   caste
# 1789  Italian honey bee  unhealthy            False  worker
# 1790  Italian honey bee  unhealthy            False  worker
# 1791  Italian honey bee  unhealthy            False  worker
# 1792  Italian honey bee  unhealthy            False  worker
# 1793  Italian honey bee  unhealthy            False  worker

# %%
bees.isna()
# Out:
#       datetime   file  location  zip code  subspecies  health  \
# 0        False  False     False     False       False   False
# 1        False  False     False     False       False   False
# 2        False  False     False     False       False   False
# 3        False  False     False     False       False   False
# 4        False  False     False     False       False   False
# ...        ...    ...       ...       ...         ...     ...
# 1789     False  False     False     False       False   False
# 1790     False  False     False     False       False   False
# 1791     False  False     False     False       False   False
# 1792     False  False     False     False       False   False
# 1793     False  False     False     False       False   False
#
#       pollen_carrying  caste
# 0               False  False
# 1               False  False
# 2               False  False
# 3               False  False
# 4               False  False
# ...               ...    ...
# 1789            False  False
# 1790            False  False
# 1791            False  False
# 1792            False  False
# 1793            False  False
#
# [1786 rows x 8 columns]

# %%
train_bees, test_bees = train_test_split(bees, random_state=65)
train_bees, val_bees = train_test_split(train_bees, test_size=0.1, random_state = 67)
ncat_bal = int(len(train_bees)/train_bees['subspecies'].cat.categories.size)
train_bees_bal = train_bees.groupby('subspecies', as_index=False).apply(lambda g:  g.sample(ncat_bal, replace=True)).reset_index(drop=True)
train_bees = train_bees_bal

# %%
train_X = np.stack(train_bees['file'].apply(read_img))
train_y  = pd.get_dummies(train_bees['subspecies'], drop_first=False)

val_X = np.stack(val_bees['file'].apply(read_img))
val_y = pd.get_dummies(val_bees['subspecies'], drop_first=False)

test_X = np.stack(test_bees['file'].apply(read_img))
test_y = pd.get_dummies(test_bees['subspecies'], drop_first=False)

# Data augmentation - a little bit rotate, zoom and shift input images.
generator = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=180,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True)
generator.fit(train_X)

# %%
earlystopper = EarlyStopping(monitor='val_accuracy', patience=25, verbose=1)
checkpointer = ModelCheckpoint('bee_subp.h5'
                                ,monitor='val_accuracy'
                                ,verbose=1
                                ,save_best_only=True
                                ,save_weights_only=True)
model=Sequential()
model.add(Conv2D(32, kernel_size=3, input_shape=(img_width, img_height,3), activation='relu', padding='same'))
model.add(MaxPool2D(2))
model.add(Dropout(0.15))
model.add(Conv2D(32, kernel_size=3, activation='relu', padding='same'))
model.add(Dropout(0.15))
model.add(Flatten())
model.add(Dense(train_y.columns.size, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

steps = np.round(train_X.shape[0] / 256, 0)
training = model.fit_generator(generator.flow(train_X,train_y, batch_size=256)
                        ,epochs=200
                        ,validation_data=(val_X, val_y)
                        ,steps_per_epoch=steps
                        ,callbacks=[earlystopper, checkpointer])
# Out:
# C:\Users\satvi\AppData\Local\Temp\ipykernel_23996\1216707429.py:18: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   training = model.fit_generator(generator.flow(train_X,train_y, batch_size=256)
# Epoch 1/200
# 5/5 [==============================] - ETA: 0s - loss: 3.4418 - accuracy: 0.3123
# Epoch 1: val_accuracy improved from -inf to 0.66418, saving model to bee_subp.h5
# 5/5 [==============================] - 20s 3s/step - loss: 3.4418 - accuracy: 0.3123 - val_loss: 2.0622 - val_accuracy: 0.6642
# Epoch 2/200
# 5/5 [==============================] - ETA: 0s - loss: 2.2127 - accuracy: 0.4136
# Epoch 2: val_accuracy did not improve from 0.66418
# 5/5 [==============================] - 16s 3s/step - loss: 2.2127 - accuracy: 0.4136 - val_loss: 1.4106 - val_accuracy: 0.1343
# Epoch 3/200
# 5/5 [==============================] - ETA: 0s - loss: 1.3154 - accuracy: 0.3248
# Epoch 3: val_accuracy did not improve from 0.66418
# 5/5 [==============================] - 15s 3s/step - loss: 1.3154 - accuracy: 0.3248 - val_loss: 1.2480 - val_accuracy: 0.4552
# Epoch 4/200
# 5/5 [==============================] - ETA: 0s - loss: 1.2291 - accuracy: 0.2857
# Epoch 4: val_accuracy improved from 0.66418 to 0.69403, saving model to bee_subp.h5
# 5/5 [==============================] - 15s 3s/step - loss: 1.2291 - accuracy: 0.2857 - val_loss: 1.1395 - val_accuracy: 0.6940
# Epoch 5/200
# 5/5 [==============================] - ETA: 0s - loss: 1.1324 - accuracy: 0.3945
# Epoch 5: val_accuracy did not improve from 0.69403
# 5/5 [==============================] - 14s 3s/step - loss: 1.1324 - accuracy: 0.3945 - val_loss: 0.9667 - val_accuracy: 0.5746
# Epoch 6/200
# 5/5 [==============================] - ETA: 0s - loss: 1.0104 - accuracy: 0.5781
# Epoch 6: val_accuracy did not improve from 0.69403
# 5/5 [==============================] - 16s 3s/step - loss: 1.0104 - accuracy: 0.5781 - val_loss: 0.8418 - val_accuracy: 0.6045
# Epoch 7/200
# 5/5 [==============================] - ETA: 0s - loss: 0.8452 - accuracy: 0.5797
# Epoch 7: val_accuracy improved from 0.69403 to 0.71642, saving model to bee_subp.h5
# 5/5 [==============================] - 15s 3s/step - loss: 0.8452 - accuracy: 0.5797 - val_loss: 0.6728 - val_accuracy: 0.7164
# Epoch 8/200
# 5/5 [==============================] - ETA: 0s - loss: 0.7212 - accuracy: 0.6113
# Epoch 8: val_accuracy improved from 0.71642 to 0.81343, saving model to bee_subp.h5
# 5/5 [==============================] - 17s 3s/step - loss: 0.7212 - accuracy: 0.6113 - val_loss: 0.5127 - val_accuracy: 0.8134
# Epoch 9/200
# 5/5 [==============================] - ETA: 0s - loss: 0.6466 - accuracy: 0.7625
# Epoch 9: val_accuracy improved from 0.81343 to 0.82836, saving model to bee_subp.h5
# 5/5 [==============================] - 16s 3s/step - loss: 0.6466 - accuracy: 0.7625 - val_loss: 0.5519 - val_accuracy: 0.8284
# Epoch 10/200
# 5/5 [==============================] - ETA: 0s - loss: 0.5337 - accuracy: 0.8223
# Epoch 10: val_accuracy improved from 0.82836 to 0.89552, saving model to bee_subp.h5
# 5/5 [==============================] - 11s 2s/step - loss: 0.5337 - accuracy: 0.8223 - val_loss: 0.4426 - val_accuracy: 0.8955
# Epoch 11/200
# 5/5 [==============================] - ETA: 0s - loss: 0.3862 - accuracy: 0.9252
# Epoch 11: val_accuracy improved from 0.89552 to 0.93284, saving model to bee_subp.h5
# 5/5 [==============================] - 16s 3s/step - loss: 0.3862 - accuracy: 0.9252 - val_loss: 0.2770 - val_accuracy: 0.9328
# Epoch 12/200
# 5/5 [==============================] - ETA: 0s - loss: 0.3196 - accuracy: 0.8912
# Epoch 12: val_accuracy improved from 0.93284 to 0.97761, saving model to bee_subp.h5
# 5/5 [==============================] - 16s 3s/step - loss: 0.3196 - accuracy: 0.8912 - val_loss: 0.1638 - val_accuracy: 0.9776
# Epoch 13/200
# 5/5 [==============================] - ETA: 0s - loss: 0.2793 - accuracy: 0.9311
# Epoch 13: val_accuracy did not improve from 0.97761
# 5/5 [==============================] - 15s 3s/step - loss: 0.2793 - accuracy: 0.9311 - val_loss: 0.1934 - val_accuracy: 0.9403
# Epoch 14/200
# 5/5 [==============================] - ETA: 0s - loss: 0.2550 - accuracy: 0.9410
# Epoch 14: val_accuracy improved from 0.97761 to 0.98507, saving model to bee_subp.h5
# 5/5 [==============================] - 16s 3s/step - loss: 0.2550 - accuracy: 0.9410 - val_loss: 0.1486 - val_accuracy: 0.9851
# Epoch 15/200
# 5/5 [==============================] - ETA: 0s - loss: 0.2096 - accuracy: 0.9477
# Epoch 15: val_accuracy did not improve from 0.98507
# 5/5 [==============================] - 16s 3s/step - loss: 0.2096 - accuracy: 0.9477 - val_loss: 0.1505 - val_accuracy: 0.9627
# Epoch 16/200
# 5/5 [==============================] - ETA: 0s - loss: 0.2011 - accuracy: 0.9468
# Epoch 16: val_accuracy did not improve from 0.98507
# 5/5 [==============================] - 15s 3s/step - loss: 0.2011 - accuracy: 0.9468 - val_loss: 0.1001 - val_accuracy: 0.9776
# Epoch 17/200
# 5/5 [==============================] - ETA: 0s - loss: 0.1806 - accuracy: 0.9427
# Epoch 17: val_accuracy did not improve from 0.98507
# 5/5 [==============================] - 17s 3s/step - loss: 0.1806 - accuracy: 0.9427 - val_loss: 0.1089 - val_accuracy: 0.9851
# Epoch 18/200
# 5/5 [==============================] - ETA: 0s - loss: 0.1785 - accuracy: 0.9610
# Epoch 18: val_accuracy did not improve from 0.98507
# 5/5 [==============================] - 13s 3s/step - loss: 0.1785 - accuracy: 0.9610 - val_loss: 0.0886 - val_accuracy: 0.9776
# Epoch 19/200
# 5/5 [==============================] - ETA: 0s - loss: 0.1409 - accuracy: 0.9535
# Epoch 19: val_accuracy did not improve from 0.98507
# 5/5 [==============================] - 15s 3s/step - loss: 0.1409 - accuracy: 0.9535 - val_loss: 0.0679 - val_accuracy: 0.9776
# Epoch 20/200
# 5/5 [==============================] - ETA: 0s - loss: 0.1548 - accuracy: 0.9551
# Epoch 20: val_accuracy did not improve from 0.98507
# 5/5 [==============================] - 17s 3s/step - loss: 0.1548 - accuracy: 0.9551 - val_loss: 0.0818 - val_accuracy: 0.9776
# Epoch 21/200
# 5/5 [==============================] - ETA: 0s - loss: 0.1355 - accuracy: 0.9576
# Epoch 21: val_accuracy did not improve from 0.98507
# 5/5 [==============================] - 15s 3s/step - loss: 0.1355 - accuracy: 0.9576 - val_loss: 0.0834 - val_accuracy: 0.9776
# Epoch 22/200
# 5/5 [==============================] - ETA: 0s - loss: 0.1082 - accuracy: 0.9709
# Epoch 22: val_accuracy did not improve from 0.98507
# 5/5 [==============================] - 17s 3s/step - loss: 0.1082 - accuracy: 0.9709 - val_loss: 0.0654 - val_accuracy: 0.9851
# Epoch 23/200
# 5/5 [==============================] - ETA: 0s - loss: 0.1071 - accuracy: 0.9668
# Epoch 23: val_accuracy did not improve from 0.98507
# 5/5 [==============================] - 18s 3s/step - loss: 0.1071 - accuracy: 0.9668 - val_loss: 0.0591 - val_accuracy: 0.9851
# Epoch 24/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0989 - accuracy: 0.9743
# Epoch 24: val_accuracy did not improve from 0.98507
# 5/5 [==============================] - 24s 4s/step - loss: 0.0989 - accuracy: 0.9743 - val_loss: 0.0581 - val_accuracy: 0.9776
# Epoch 25/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0977 - accuracy: 0.9701
# Epoch 25: val_accuracy did not improve from 0.98507
# 5/5 [==============================] - 23s 4s/step - loss: 0.0977 - accuracy: 0.9701 - val_loss: 0.0484 - val_accuracy: 0.9851
# Epoch 26/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9759
# Epoch 26: val_accuracy improved from 0.98507 to 0.99254, saving model to bee_subp.h5
# 5/5 [==============================] - 12s 2s/step - loss: 0.0839 - accuracy: 0.9759 - val_loss: 0.0462 - val_accuracy: 0.9925
# Epoch 27/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0933 - accuracy: 0.9709
# Epoch 27: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 9s 2s/step - loss: 0.0933 - accuracy: 0.9709 - val_loss: 0.0423 - val_accuracy: 0.9851
# Epoch 28/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0979 - accuracy: 0.9718
# Epoch 28: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 9s 2s/step - loss: 0.0979 - accuracy: 0.9718 - val_loss: 0.0431 - val_accuracy: 0.9851
# Epoch 29/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0820 - accuracy: 0.9751
# Epoch 29: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 9s 2s/step - loss: 0.0820 - accuracy: 0.9751 - val_loss: 0.0426 - val_accuracy: 0.9851
# Epoch 30/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0861 - accuracy: 0.9734
# Epoch 30: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 8s 2s/step - loss: 0.0861 - accuracy: 0.9734 - val_loss: 0.0429 - val_accuracy: 0.9851
# Epoch 31/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0635 - accuracy: 0.9867
# Epoch 31: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 10s 2s/step - loss: 0.0635 - accuracy: 0.9867 - val_loss: 0.0407 - val_accuracy: 0.9925
# Epoch 32/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0673 - accuracy: 0.9817
# Epoch 32: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 8s 2s/step - loss: 0.0673 - accuracy: 0.9817 - val_loss: 0.0353 - val_accuracy: 0.9851
# Epoch 33/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9859
# Epoch 33: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 8s 2s/step - loss: 0.0551 - accuracy: 0.9859 - val_loss: 0.0420 - val_accuracy: 0.9851
# Epoch 34/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0556 - accuracy: 0.9884
# Epoch 34: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 10s 2s/step - loss: 0.0556 - accuracy: 0.9884 - val_loss: 0.0442 - val_accuracy: 0.9925
# Epoch 35/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.9801
# Epoch 35: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 9s 2s/step - loss: 0.0610 - accuracy: 0.9801 - val_loss: 0.0377 - val_accuracy: 0.9925
# Epoch 36/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 0.9817
# Epoch 36: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 9s 2s/step - loss: 0.0532 - accuracy: 0.9817 - val_loss: 0.0338 - val_accuracy: 0.9925
# Epoch 37/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0521 - accuracy: 0.9859
# Epoch 37: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 8s 2s/step - loss: 0.0521 - accuracy: 0.9859 - val_loss: 0.0337 - val_accuracy: 0.9925
# Epoch 38/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0560 - accuracy: 0.9842
# Epoch 38: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 10s 2s/step - loss: 0.0560 - accuracy: 0.9842 - val_loss: 0.0290 - val_accuracy: 0.9925
# Epoch 39/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9875
# Epoch 39: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 8s 2s/step - loss: 0.0448 - accuracy: 0.9875 - val_loss: 0.0243 - val_accuracy: 0.9925
# Epoch 40/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9867
# Epoch 40: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 8s 2s/step - loss: 0.0478 - accuracy: 0.9867 - val_loss: 0.0320 - val_accuracy: 0.9925
# Epoch 41/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9900
# Epoch 41: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 9s 2s/step - loss: 0.0456 - accuracy: 0.9900 - val_loss: 0.0276 - val_accuracy: 0.9925
# Epoch 42/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 0.9842
# Epoch 42: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 8s 1s/step - loss: 0.0469 - accuracy: 0.9842 - val_loss: 0.0314 - val_accuracy: 0.9925
# Epoch 43/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9884
# Epoch 43: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 8s 2s/step - loss: 0.0378 - accuracy: 0.9884 - val_loss: 0.0349 - val_accuracy: 0.9851
# Epoch 44/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0531 - accuracy: 0.9850
# Epoch 44: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 9s 2s/step - loss: 0.0531 - accuracy: 0.9850 - val_loss: 0.0325 - val_accuracy: 0.9925
# Epoch 45/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.9909
# Epoch 45: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 9s 2s/step - loss: 0.0447 - accuracy: 0.9909 - val_loss: 0.0336 - val_accuracy: 0.9851
# Epoch 46/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0429 - accuracy: 0.9917
# Epoch 46: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 8s 1s/step - loss: 0.0429 - accuracy: 0.9917 - val_loss: 0.0293 - val_accuracy: 0.9925
# Epoch 47/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0394 - accuracy: 0.9892
# Epoch 47: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 8s 2s/step - loss: 0.0394 - accuracy: 0.9892 - val_loss: 0.0247 - val_accuracy: 0.9925
# Epoch 48/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0338 - accuracy: 0.9934
# Epoch 48: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 11s 2s/step - loss: 0.0338 - accuracy: 0.9934 - val_loss: 0.0310 - val_accuracy: 0.9925
# Epoch 49/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0330 - accuracy: 0.9925
# Epoch 49: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 9s 2s/step - loss: 0.0330 - accuracy: 0.9925 - val_loss: 0.0351 - val_accuracy: 0.9925
# Epoch 50/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9934
# Epoch 50: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 8s 2s/step - loss: 0.0285 - accuracy: 0.9934 - val_loss: 0.0308 - val_accuracy: 0.9851
# Epoch 51/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9925
# Epoch 51: val_accuracy did not improve from 0.99254
# 5/5 [==============================] - 8s 2s/step - loss: 0.0283 - accuracy: 0.9925 - val_loss: 0.0235 - val_accuracy: 0.9925
# Epoch 51: early stopping

# %%
model_json = model.to_json()
with open("Subspecies_placeholder.json", "w") as json_file:
    json_file.write(model_json)

# Save the best model weights
model.save_weights("bee_subp.h5")

# Save Subspecies Prediction Placeholder
# with open("subspecies_placeholder.txt", "w") as subspecies_file:
#     subspecies_file.write("Subspecies Prediction Placeholder")
# # Save model weights
# model.save_weights('best.h5')
test_res = model.evaluate(test_X, test_y.values, verbose=0)
print('Loss function: %s, accuracy:' % test_res[0], test_res[1])
# Out:
# Loss function: 0.03911426663398743, accuracy: 0.9932885766029358

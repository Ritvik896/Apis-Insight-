# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.model_selection import train_test_split
import tensorflow
import skimage
import skimage.io
import skimage.transform
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPool2D
from keras.layers import Dropout, BatchNormalization,LeakyReLU, Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, ReduceLROnPlateau
from keras.utils import to_categorical
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Load the saved model
from keras.models import model_from_json

# %%
np.random.seed(11)
tensorflow.random.set_seed(11)

# %%
img_folder='C:\\Users\\satvi\\OneDrive\\Pictures\\Desktop\\Test1\\static1\\images\\'
img_width=128
#check path
img_height=128
img_channels=3
bees=pd.read_csv('C:\\Users\\satvi\\OneDrive\\Pictures\\Desktop\\Test1\\bee_data_mod.csv', 
                index_col=False,  
                parse_dates={'datetime':[1,2]},
                dtype={'subspecies':'category', 'health':'category','caste':'category'})
def read_img(file):
    img = skimage.io.imread(img_folder + file)
    img = skimage.transform.resize(img, (img_width, img_height), mode='reflect')
    return img[:,:,:img_channels]

bees.dropna(inplace=True)
img_exists = bees['file'].apply(lambda f: os.path.exists(img_folder + f))
bees = bees[img_exists]
# Out:
# C:\Users\satvi\AppData\Local\Temp\ipykernel_5308\2525093836.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bees=pd.read_csv('C:\\Users\\satvi\\OneDrive\\Pictures\\Desktop\\Test1\\bee_data_mod.csv',

# %%
bees.head()
# Out:
#              datetime         file              location  zip code  \
# 0 2018-08-25 14:00:00  001_043.png  Kalakadu, Tamil Nadu    627007
# 1 2018-08-25 14:00:00  001_044.png  Kalakadu, Tamil Nadu    627007
# 2 2018-08-25 14:00:00  001_046.png  Kalakadu, Tamil Nadu    627007
# 3 2018-08-25 14:00:00  001_047.png  Kalakadu, Tamil Nadu    627007
# 4 2018-08-25 14:00:00  001_050.png  Kalakadu, Tamil Nadu    627007
#
#    subspecies   health  pollen_carrying   caste
# 0  Dammer bee  healthy            False  worker
# 1  Dammer bee  healthy            False  worker
# 2  Dammer bee  healthy            False  worker
# 3  Dammer bee  healthy            False  worker
# 4  Dammer bee  healthy            False  worker

# %%
bees.tail()
# Out:
#                 datetime         file              location  zip code  \
# 1789 2018-08-17 17:50:00  030_800.png  Alchuna, Uttrakhand     263136
# 1790 2018-08-17 17:50:00  030_814.png  Alchuna, Uttrakhand     263136
# 1791 2018-08-17 17:50:00  030_828.png  Alchuna, Uttrakhand     263136
# 1792 2018-08-17 17:50:00  030_829.png  Alchuna, Uttrakhand     263136
# 1793 2018-08-17 17:50:00  030_815.png  Alchuna, Uttrakhand     263136
#
#              subspecies     health  pollen_carrying   caste
# 1789  Italian honey bee  unhealthy            False  worker
# 1790  Italian honey bee  unhealthy            False  worker
# 1791  Italian honey bee  unhealthy            False  worker
# 1792  Italian honey bee  unhealthy            False  worker
# 1793  Italian honey bee  unhealthy            False  worker

# %%
bees.isna()
# Out:
#       datetime   file  location  zip code  subspecies  health  \
# 0        False  False     False     False       False   False
# 1        False  False     False     False       False   False
# 2        False  False     False     False       False   False
# 3        False  False     False     False       False   False
# 4        False  False     False     False       False   False
# ...        ...    ...       ...       ...         ...     ...
# 1789     False  False     False     False       False   False
# 1790     False  False     False     False       False   False
# 1791     False  False     False     False       False   False
# 1792     False  False     False     False       False   False
# 1793     False  False     False     False       False   False
#
#       pollen_carrying  caste
# 0               False  False
# 1               False  False
# 2               False  False
# 3               False  False
# 4               False  False
# ...               ...    ...
# 1789            False  False
# 1790            False  False
# 1791            False  False
# 1792            False  False
# 1793            False  False
#
# [1786 rows x 8 columns]

# %%
train_bees, test_bees = train_test_split(bees, random_state=65)
train_bees, val_bees = train_test_split(train_bees, test_size=0.1, random_state = 67)
ncat_bal = int(len(train_bees)/train_bees['health'].cat.categories.size)
train_bees_bal = train_bees.groupby('health', as_index=False).apply(lambda g:  g.sample(ncat_bal, replace=True)).reset_index(drop=True)
train_bees = train_bees_bal

# %%
train_X = np.stack(train_bees['file'].apply(read_img))
train_y  = pd.get_dummies(train_bees['health'], drop_first=False)

val_X = np.stack(val_bees['file'].apply(read_img))
val_y = pd.get_dummies(val_bees['health'], drop_first=False)

test_X = np.stack(test_bees['file'].apply(read_img))
test_y = pd.get_dummies(test_bees['health'], drop_first=False)

# Data augmentation - a little bit rotate, zoom and shift input images.
generator = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=180,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True)
generator.fit(train_X)

# %%
earlystopper = EarlyStopping(monitor='val_accuracy', patience=25, verbose=1)
checkpointer = ModelCheckpoint('bee_health.h5'
                                ,monitor='val_accuracy'
                                ,verbose=1
                                ,save_best_only=True
                                ,save_weights_only=True)
model=Sequential()
model.add(Conv2D(32, kernel_size=3, input_shape=(img_width, img_height,3), activation='relu', padding='same'))
model.add(MaxPool2D(2))
model.add(Dropout(0.15))
model.add(Conv2D(32, kernel_size=3, activation='relu', padding='same'))
model.add(Dropout(0.15))
model.add(Flatten())
model.add(Dense(train_y.columns.size, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

steps = np.round(train_X.shape[0] / 256, 0)
training = model.fit_generator(generator.flow(train_X,train_y, batch_size=256)
                        ,epochs=200
                        ,validation_data=(val_X, val_y)
                        ,steps_per_epoch=steps
                        ,callbacks=[earlystopper, checkpointer])
# Out:
# C:\Users\satvi\AppData\Local\Temp\ipykernel_5308\4075310022.py:18: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   training = model.fit_generator(generator.flow(train_X,train_y, batch_size=256)
# Epoch 1/200
# 5/5 [==============================] - ETA: 0s - loss: 3.0754 - accuracy: 0.3441
# Epoch 1: val_accuracy improved from -inf to 0.01493, saving model to bee_health.h5
# 5/5 [==============================] - 12s 2s/step - loss: 3.0754 - accuracy: 0.3441 - val_loss: 3.0276 - val_accuracy: 0.0149
# Epoch 2/200
# 5/5 [==============================] - ETA: 0s - loss: 1.4024 - accuracy: 0.3608
# Epoch 2: val_accuracy improved from 0.01493 to 0.54478, saving model to bee_health.h5
# 5/5 [==============================] - 10s 2s/step - loss: 1.4024 - accuracy: 0.3608 - val_loss: 0.9298 - val_accuracy: 0.5448
# Epoch 3/200
# 5/5 [==============================] - ETA: 0s - loss: 1.0904 - accuracy: 0.3608
# Epoch 3: val_accuracy improved from 0.54478 to 0.71642, saving model to bee_health.h5
# 5/5 [==============================] - 9s 2s/step - loss: 1.0904 - accuracy: 0.3608 - val_loss: 0.9353 - val_accuracy: 0.7164
# Epoch 4/200
# 5/5 [==============================] - ETA: 0s - loss: 1.0549 - accuracy: 0.4281
# Epoch 4: val_accuracy improved from 0.71642 to 0.76866, saving model to bee_health.h5
# 5/5 [==============================] - 10s 2s/step - loss: 1.0549 - accuracy: 0.4281 - val_loss: 1.0642 - val_accuracy: 0.7687
# Epoch 5/200
# 5/5 [==============================] - ETA: 0s - loss: 1.0195 - accuracy: 0.3458
# Epoch 5: val_accuracy did not improve from 0.76866
# 5/5 [==============================] - 10s 2s/step - loss: 1.0195 - accuracy: 0.3458 - val_loss: 1.0142 - val_accuracy: 0.7090
# Epoch 6/200
# 5/5 [==============================] - ETA: 0s - loss: 0.9316 - accuracy: 0.6027
# Epoch 6: val_accuracy did not improve from 0.76866
# 5/5 [==============================] - 8s 1s/step - loss: 0.9316 - accuracy: 0.6027 - val_loss: 0.8752 - val_accuracy: 0.5448
# Epoch 7/200
# 5/5 [==============================] - ETA: 0s - loss: 0.8214 - accuracy: 0.6326
# Epoch 7: val_accuracy did not improve from 0.76866
# 5/5 [==============================] - 9s 2s/step - loss: 0.8214 - accuracy: 0.6326 - val_loss: 0.7596 - val_accuracy: 0.6194
# Epoch 8/200
# 5/5 [==============================] - ETA: 0s - loss: 0.7607 - accuracy: 0.6625
# Epoch 8: val_accuracy did not improve from 0.76866
# 5/5 [==============================] - 18s 3s/step - loss: 0.7607 - accuracy: 0.6625 - val_loss: 0.8708 - val_accuracy: 0.5000
# Epoch 9/200
# 5/5 [==============================] - ETA: 0s - loss: 0.7021 - accuracy: 0.6949
# Epoch 9: val_accuracy improved from 0.76866 to 0.80597, saving model to bee_health.h5
# 5/5 [==============================] - 10s 2s/step - loss: 0.7021 - accuracy: 0.6949 - val_loss: 0.6754 - val_accuracy: 0.8060
# Epoch 10/200
# 5/5 [==============================] - ETA: 0s - loss: 0.6428 - accuracy: 0.7323
# Epoch 10: val_accuracy improved from 0.80597 to 0.81343, saving model to bee_health.h5
# 5/5 [==============================] - 9s 2s/step - loss: 0.6428 - accuracy: 0.7323 - val_loss: 0.5989 - val_accuracy: 0.8134
# Epoch 11/200
# 5/5 [==============================] - ETA: 0s - loss: 0.5826 - accuracy: 0.7365
# Epoch 11: val_accuracy did not improve from 0.81343
# 5/5 [==============================] - 11s 2s/step - loss: 0.5826 - accuracy: 0.7365 - val_loss: 0.6836 - val_accuracy: 0.7463
# Epoch 12/200
# 5/5 [==============================] - ETA: 0s - loss: 0.5008 - accuracy: 0.7905
# Epoch 12: val_accuracy did not improve from 0.81343
# 5/5 [==============================] - 9s 2s/step - loss: 0.5008 - accuracy: 0.7905 - val_loss: 0.5853 - val_accuracy: 0.6194
# Epoch 13/200
# 5/5 [==============================] - ETA: 0s - loss: 0.4489 - accuracy: 0.8105
# Epoch 13: val_accuracy improved from 0.81343 to 0.88060, saving model to bee_health.h5
# 5/5 [==============================] - 8s 2s/step - loss: 0.4489 - accuracy: 0.8105 - val_loss: 0.3198 - val_accuracy: 0.8806
# Epoch 14/200
# 5/5 [==============================] - ETA: 0s - loss: 0.3842 - accuracy: 0.8562
# Epoch 14: val_accuracy did not improve from 0.88060
# 5/5 [==============================] - 8s 2s/step - loss: 0.3842 - accuracy: 0.8562 - val_loss: 0.4420 - val_accuracy: 0.7910
# Epoch 15/200
# 5/5 [==============================] - ETA: 0s - loss: 0.3499 - accuracy: 0.8662
# Epoch 15: val_accuracy did not improve from 0.88060
# 5/5 [==============================] - 9s 2s/step - loss: 0.3499 - accuracy: 0.8662 - val_loss: 0.4068 - val_accuracy: 0.8358
# Epoch 16/200
# 5/5 [==============================] - ETA: 0s - loss: 0.3046 - accuracy: 0.8953
# Epoch 16: val_accuracy did not improve from 0.88060
# 5/5 [==============================] - 7s 1s/step - loss: 0.3046 - accuracy: 0.8953 - val_loss: 0.3927 - val_accuracy: 0.8657
# Epoch 17/200
# 5/5 [==============================] - ETA: 0s - loss: 0.2786 - accuracy: 0.9061
# Epoch 17: val_accuracy improved from 0.88060 to 0.88806, saving model to bee_health.h5
# 5/5 [==============================] - 7s 1s/step - loss: 0.2786 - accuracy: 0.9061 - val_loss: 0.2790 - val_accuracy: 0.8881
# Epoch 18/200
# 5/5 [==============================] - ETA: 0s - loss: 0.2537 - accuracy: 0.9135
# Epoch 18: val_accuracy improved from 0.88806 to 0.91045, saving model to bee_health.h5
# 5/5 [==============================] - 8s 2s/step - loss: 0.2537 - accuracy: 0.9135 - val_loss: 0.2116 - val_accuracy: 0.9104
# Epoch 19/200
# 5/5 [==============================] - ETA: 0s - loss: 0.2334 - accuracy: 0.9119
# Epoch 19: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 11s 2s/step - loss: 0.2334 - accuracy: 0.9119 - val_loss: 0.2255 - val_accuracy: 0.9104
# Epoch 20/200
# 5/5 [==============================] - ETA: 0s - loss: 0.2128 - accuracy: 0.9327
# Epoch 20: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 8s 2s/step - loss: 0.2128 - accuracy: 0.9327 - val_loss: 0.3370 - val_accuracy: 0.8657
# Epoch 21/200
# 5/5 [==============================] - ETA: 0s - loss: 0.2081 - accuracy: 0.9268
# Epoch 21: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 8s 1s/step - loss: 0.2081 - accuracy: 0.9268 - val_loss: 0.2738 - val_accuracy: 0.8806
# Epoch 22/200
# 5/5 [==============================] - ETA: 0s - loss: 0.1804 - accuracy: 0.9360
# Epoch 22: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 9s 2s/step - loss: 0.1804 - accuracy: 0.9360 - val_loss: 0.2429 - val_accuracy: 0.8955
# Epoch 23/200
# 5/5 [==============================] - ETA: 0s - loss: 0.1660 - accuracy: 0.9426
# Epoch 23: val_accuracy did not improve from 0.91045
# 5/5 [==============================] - 8s 2s/step - loss: 0.1660 - accuracy: 0.9426 - val_loss: 0.2267 - val_accuracy: 0.9104
# Epoch 24/200
# 5/5 [==============================] - ETA: 0s - loss: 0.1533 - accuracy: 0.9451
# Epoch 24: val_accuracy improved from 0.91045 to 0.91791, saving model to bee_health.h5
# 5/5 [==============================] - 7s 1s/step - loss: 0.1533 - accuracy: 0.9451 - val_loss: 0.1918 - val_accuracy: 0.9179
# Epoch 25/200
# 5/5 [==============================] - ETA: 0s - loss: 0.1363 - accuracy: 0.9568
# Epoch 25: val_accuracy improved from 0.91791 to 0.95522, saving model to bee_health.h5
# 5/5 [==============================] - 8s 2s/step - loss: 0.1363 - accuracy: 0.9568 - val_loss: 0.1323 - val_accuracy: 0.9552
# Epoch 26/200
# 5/5 [==============================] - ETA: 0s - loss: 0.1292 - accuracy: 0.9518
# Epoch 26: val_accuracy improved from 0.95522 to 0.98507, saving model to bee_health.h5
# 5/5 [==============================] - 8s 1s/step - loss: 0.1292 - accuracy: 0.9518 - val_loss: 0.0755 - val_accuracy: 0.9851
# Epoch 27/200
# 5/5 [==============================] - ETA: 0s - loss: 0.1145 - accuracy: 0.9626
# Epoch 27: val_accuracy did not improve from 0.98507
# 5/5 [==============================] - 8s 1s/step - loss: 0.1145 - accuracy: 0.9626 - val_loss: 0.0737 - val_accuracy: 0.9851
# Epoch 28/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0964 - accuracy: 0.9742
# Epoch 28: val_accuracy did not improve from 0.98507
# 5/5 [==============================] - 10s 2s/step - loss: 0.0964 - accuracy: 0.9742 - val_loss: 0.1709 - val_accuracy: 0.9403
# Epoch 29/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9717
# Epoch 29: val_accuracy did not improve from 0.98507
# 5/5 [==============================] - 10s 2s/step - loss: 0.0998 - accuracy: 0.9717 - val_loss: 0.1035 - val_accuracy: 0.9478
# Epoch 30/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0928 - accuracy: 0.9717
# Epoch 30: val_accuracy did not improve from 0.98507
# 5/5 [==============================] - 9s 2s/step - loss: 0.0928 - accuracy: 0.9717 - val_loss: 0.0974 - val_accuracy: 0.9627
# Epoch 31/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0699 - accuracy: 0.9834
# Epoch 31: val_accuracy did not improve from 0.98507
# 5/5 [==============================] - 9s 2s/step - loss: 0.0699 - accuracy: 0.9834 - val_loss: 0.0895 - val_accuracy: 0.9627
# Epoch 32/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0715 - accuracy: 0.9817
# Epoch 32: val_accuracy improved from 0.98507 to 1.00000, saving model to bee_health.h5
# 5/5 [==============================] - 10s 2s/step - loss: 0.0715 - accuracy: 0.9817 - val_loss: 0.0463 - val_accuracy: 1.0000
# Epoch 33/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0636 - accuracy: 0.9842
# Epoch 33: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 10s 2s/step - loss: 0.0636 - accuracy: 0.9842 - val_loss: 0.0446 - val_accuracy: 1.0000
# Epoch 34/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.9867
# Epoch 34: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 16s 3s/step - loss: 0.0574 - accuracy: 0.9867 - val_loss: 0.0455 - val_accuracy: 1.0000
# Epoch 35/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0632 - accuracy: 0.9800
# Epoch 35: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 15s 3s/step - loss: 0.0632 - accuracy: 0.9800 - val_loss: 0.0304 - val_accuracy: 1.0000
# Epoch 36/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9900
# Epoch 36: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 15s 3s/step - loss: 0.0544 - accuracy: 0.9900 - val_loss: 0.0744 - val_accuracy: 0.9552
# Epoch 37/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0539 - accuracy: 0.9859
# Epoch 37: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 15s 3s/step - loss: 0.0539 - accuracy: 0.9859 - val_loss: 0.1137 - val_accuracy: 0.9403
# Epoch 38/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9900
# Epoch 38: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 15s 3s/step - loss: 0.0453 - accuracy: 0.9900 - val_loss: 0.1171 - val_accuracy: 0.9328
# Epoch 39/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 0.9842
# Epoch 39: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 17s 3s/step - loss: 0.0541 - accuracy: 0.9842 - val_loss: 0.1880 - val_accuracy: 0.9403
# Epoch 40/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0780 - accuracy: 0.9734
# Epoch 40: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 15s 3s/step - loss: 0.0780 - accuracy: 0.9734 - val_loss: 0.1079 - val_accuracy: 0.9403
# Epoch 41/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0604 - accuracy: 0.9842
# Epoch 41: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 18s 3s/step - loss: 0.0604 - accuracy: 0.9842 - val_loss: 0.0636 - val_accuracy: 0.9701
# Epoch 42/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9701
# Epoch 42: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 16s 3s/step - loss: 0.0824 - accuracy: 0.9701 - val_loss: 0.1024 - val_accuracy: 0.9552
# Epoch 43/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0912 - accuracy: 0.9659
# Epoch 43: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 16s 3s/step - loss: 0.0912 - accuracy: 0.9659 - val_loss: 0.1291 - val_accuracy: 0.9478
# Epoch 44/200
# 5/5 [==============================] - ETA: 0s - loss: 0.1359 - accuracy: 0.9551
# Epoch 44: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 15s 3s/step - loss: 0.1359 - accuracy: 0.9551 - val_loss: 0.0654 - val_accuracy: 0.9776
# Epoch 45/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0821 - accuracy: 0.9734
# Epoch 45: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 15s 3s/step - loss: 0.0821 - accuracy: 0.9734 - val_loss: 0.0754 - val_accuracy: 0.9552
# Epoch 46/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0577 - accuracy: 0.9842
# Epoch 46: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 16s 3s/step - loss: 0.0577 - accuracy: 0.9842 - val_loss: 0.0397 - val_accuracy: 0.9925
# Epoch 47/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0444 - accuracy: 0.9884
# Epoch 47: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 16s 3s/step - loss: 0.0444 - accuracy: 0.9884 - val_loss: 0.0692 - val_accuracy: 0.9627
# Epoch 48/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0459 - accuracy: 0.9909
# Epoch 48: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 16s 3s/step - loss: 0.0459 - accuracy: 0.9909 - val_loss: 0.0436 - val_accuracy: 0.9851
# Epoch 49/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9942
# Epoch 49: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 16s 4s/step - loss: 0.0346 - accuracy: 0.9942 - val_loss: 0.0597 - val_accuracy: 0.9701
# Epoch 50/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9933
# Epoch 50: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 15s 3s/step - loss: 0.0268 - accuracy: 0.9933 - val_loss: 0.0641 - val_accuracy: 0.9627
# Epoch 51/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0313 - accuracy: 0.9900
# Epoch 51: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 18s 3s/step - loss: 0.0313 - accuracy: 0.9900 - val_loss: 0.0557 - val_accuracy: 0.9701
# Epoch 52/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9942
# Epoch 52: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 15s 3s/step - loss: 0.0274 - accuracy: 0.9942 - val_loss: 0.0647 - val_accuracy: 0.9776
# Epoch 53/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9950
# Epoch 53: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 16s 3s/step - loss: 0.0245 - accuracy: 0.9950 - val_loss: 0.0709 - val_accuracy: 0.9776
# Epoch 54/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0216 - accuracy: 0.9967
# Epoch 54: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 15s 3s/step - loss: 0.0216 - accuracy: 0.9967 - val_loss: 0.0863 - val_accuracy: 0.9552
# Epoch 55/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9950
# Epoch 55: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 21s 4s/step - loss: 0.0203 - accuracy: 0.9950 - val_loss: 0.0564 - val_accuracy: 0.9851
# Epoch 56/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9950
# Epoch 56: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 24s 4s/step - loss: 0.0191 - accuracy: 0.9950 - val_loss: 0.0293 - val_accuracy: 0.9851
# Epoch 57/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9942
# Epoch 57: val_accuracy did not improve from 1.00000
# 5/5 [==============================] - 21s 4s/step - loss: 0.0209 - accuracy: 0.9942 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 57: early stopping

# %%
# model.load_weights('C:\\Users\\satvi\\OneDrive\\Desktop\\Bee(current 2)\\best.h5')
# model_json = model.to_json()
# with open("model_architecture.json", "w") as json_file:
#     json_file.write(model_json)
model_json = model.to_json()
with open("health.json", "w") as json_file:
    json_file.write(model_json)

# Save the best model weights
model.save_weights("bee_health.h5")

# Save Subspecies Prediction Placeholder
# with open("subspecies_placeholder.txt", "w") as subspecies_file:
#     subspecies_file.write("Subspecies Prediction Placeholder")
# Save model weights
# model.save_weights('best.h5')
test_res = model.evaluate(test_X, test_y.values, verbose=0)
predictions = model.predict(test_X)

# Convert one-hot encoded predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(test_y.values, axis=1)

# Calculate evaluation metrics
accuracy = accuracy_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels, average='macro')
recall = recall_score(true_labels, predicted_labels, average='macro')
f1 = f1_score(true_labels, predicted_labels, average='macro')

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
# Out:
# 14/14 [==============================] - 1s 50ms/step
# Accuracy: 0.9932885906040269
# Precision: 0.9476859664125582
# Recall: 0.9943607422540005
# F1-score: 0.9691911809002288
